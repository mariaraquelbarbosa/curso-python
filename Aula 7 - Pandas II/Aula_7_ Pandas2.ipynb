# %% [markdown]
# # <font color=blue>**Pandas II - Aplicações na Vida Real - FEA.dev**</font>

# %% [markdown]
# Após a aula introdutória de Pandas vamos nos aprofundar mais em algumas funcionalidades da biblioteca.

# %% [markdown]
# # <font color=blue>Sumário</font>

# %% [markdown]
# - ### 1. Introdução
#
#         1.1 Apresentação das bases de dados
#         1.2 Loc e iloc
#
# - ### 2. Métodos Úteis
#
#         2.1 Agrupamento
#         2.1.1 Groupby
#         2.1.2 Pivot Table
#         2.1.3 Melt
#
#         2.2.1 Diff
#         2.2.2 Pct_change
#
# - ### 3. Aplicações úteis
#
#         3.1 Cálculo de retorno
#         3.2 Melhores retornos para cada fundos
#         3.3 Juntando os Resultados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 1. Introdução

# %% [markdown]
# ### 1.1 Apresentação das bases de dados

# %%
ct = pd.read_csv("carteiras.csv", parse_dates=["data"])
at = pd.read_csv("ativos.csv", index_col=0, parse_dates=True)

# %%
ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2292 entries, 0 to 2291
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cnpj_gestor  2292 non-null   object
#  1   nome_gestor  2292 non-null   object
#  2   nome_fundo   2292 non-null   object
#  3   ativo        2292 non-null   object
#  4   ativo_desc   2292 non-null   object
#  5   data         2292 non-null   datetime64[ns]
#  6   cnpj_fundo   2292 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 125.5+ KB

# %%
ct.describe()
# Out:
# C:\Users\Joel\AppData\Local\Temp\ipykernel_9208\964448758.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   ct.describe()
#                cnpj_gestor                  nome_gestor  \
# count                 2292                         2292
# unique                   2                            2
# top     11.180.009/0001-48  KAPITALO INVESTIMENTOS LTDA
# freq                  1710                         1710
# first                  NaN                          NaN
# last                   NaN                          NaN
#
#                                                nome_fundo  ativo ativo_desc  \
# count                                                2292   2292       2292
# unique                                                  2    236         20
# top     KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO E...  ITUB4      Ações
# freq                                                 1710     34       1126
# first                                                 NaN    NaN        NaN
# last                                                  NaN    NaN        NaN
#
#                        data          cnpj_fundo
# count                  2292                2292
# unique                   13                   2
# top     2021-08-31 00:00:00  28.747.676/0001-62
# freq                    196                1710
# first   2021-06-30 00:00:00                 NaN
# last    2022-06-30 00:00:00                 NaN

# %%
ct.head()
# Out:
#           cnpj_gestor                               nome_gestor  \
# 0  40.788.864/0001-34  TOWER THREE RV GESTORA DE RECURSOS LTDA.
# 1  11.180.009/0001-48               KAPITALO INVESTIMENTOS LTDA
# 2  11.180.009/0001-48               KAPITALO INVESTIMENTOS LTDA
# 3  11.180.009/0001-48               KAPITALO INVESTIMENTOS LTDA
# 4  11.180.009/0001-48               KAPITALO INVESTIMENTOS LTDA
#
#                                           nome_fundo              ativo  \
# 0  T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO ...  Valores a Receber
# 1  KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO E...              ECOR3
# 2  KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO E...              AERI3
# 3  KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO E...              LWSA3
# 4  KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO E...             BPAC11
#
#                                  ativo_desc       data          cnpj_fundo
# 0                         Valores a receber 2021-06-30  41.902.620/0001-01
# 1  Ações e outros TVM cedidos em empréstimo 2021-06-30  28.747.676/0001-62
# 2  Ações e outros TVM cedidos em empréstimo 2021-06-30  28.747.676/0001-62
# 3  Ações e outros TVM cedidos em empréstimo 2021-06-30  28.747.676/0001-62
# 4  Ações e outros TVM cedidos em empréstimo 2021-06-30  28.747.676/0001-62

# %%
at.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 146 entries, 2021-12-31 to 2022-07-29
# Columns: 131 entries, BPAC5 to ELET3
# dtypes: float64(131)
# memory usage: 150.6 KB

# %%
at.describe()
# Out:
#             BPAC5       RAPT4       CMIG4       MELK3       DIRR3       PLPL3  \
# count  146.000000  146.000000  146.000000  146.000000  146.000000  146.000000
# mean    98.162615   97.420112  108.039387  100.535134   90.203315   88.065950
# std      6.537830    5.340099    8.541997    5.212278    8.161694   13.233148
# min     83.602562   85.004600   92.677346   90.991839   72.541306   62.528290
# 25%     93.907063   93.969811   99.084668   96.968514   84.205350   79.137367
# 50%     98.281616   97.608096  110.080642  100.000000   90.415769   86.861317
# 75%    103.045018  100.137994  114.676172  103.846154   95.043273   95.732910
# max    113.155095  110.763569  125.695817  117.435897  109.362707  118.153846
#
#             BPAN4       BRAP4  27.635.189/0001-45  34.964.555/0001-75  ...  \
# count  146.000000  146.000000                 5.0                 5.0  ...
# mean    82.746067  116.894476               100.0               100.0  ...
# std     14.924695   12.709496                 0.0                 0.0  ...
# min     57.393461   93.931824               100.0               100.0  ...
# 25%     66.763342  108.366036               100.0               100.0  ...
# 50%     89.419476  115.886290               100.0               100.0  ...
# 75%     94.054307  126.327941               100.0               100.0  ...
# max    105.711610  145.818327               100.0               100.0  ...
#
#             ITUB3       AURE3       WEGE3       BRPR3       HBSA3       EVEN3  \
# count  146.000000  146.000000  146.000000  146.000000  146.000000  146.000000
# mean   111.922309   93.264647   88.963170  112.113664   82.983919   86.149625
# std      6.320439    6.851411    8.996036   11.877307   11.082259   12.099884
# min    100.000000   78.529763   69.781618   85.088919   57.971014   65.705615
# 25%    106.613819   87.079622   80.795428  100.718194   79.710145   76.138088
# 50%    111.804302   95.548780   90.144483  116.762013   84.347826   85.280728
# 75%    116.803537  100.000000   95.999394  121.779942   90.434783   94.044006
# max    125.696744  101.219512  108.141640  134.549705  105.507246  114.719272
#
#             UGPA3       NEOE3       TCSA3       ELET3
# count  146.000000  146.000000  146.000000  146.000000
# mean    94.253878  103.597014   79.402725  117.447003
# std      6.340143    8.707615   15.306298   15.090912
# min     83.464453   88.375154   49.584488   88.237055
# 25%     89.120271   97.694089   65.443213  102.903322
# 50%     93.581838  101.430001   81.717452  120.309458
# 75%     99.845254  108.886258   91.897507  131.580244
# max    108.665750  122.674881  106.648199  140.872656
#
# [8 rows x 131 columns]

# %%
at.head()
# Out:
#                  BPAC5       RAPT4       CMIG4       MELK3       DIRR3  \
# data
# 2021-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-03   96.153846   99.080037   98.245614   99.487179   95.594020
# 2022-01-04   94.423077   97.884085   98.169336   98.974359   92.210858
# 2022-01-05   86.730769   94.388224   95.041953   97.179487   85.995279
# 2022-01-06   84.574684   95.676173   92.982456   95.641026   84.107002
#
#                  PLPL3       BPAN4       BRAP4  27.635.189/0001-45  \
# data
# 2021-12-31  100.000000  100.000000  100.000000               100.0
# 2022-01-03   95.692308   95.786517   98.639456               100.0
# 2022-01-04   93.846154   88.295880   99.559824               100.0
# 2022-01-05   86.461538   88.576779   99.799920               100.0
# 2022-01-06   84.923077   89.513109  102.641056               100.0
#
#             34.964.555/0001-75  ...       ITUB3  AURE3       WEGE3  \
# data                            ...
# 2021-12-31               100.0  ...  100.000000  100.0  100.000000
# 2022-01-03               100.0  ...  101.613068  100.0   97.089145
# 2022-01-04               100.0  ...  103.867641  100.0   96.604002
# 2022-01-05               100.0  ...  101.770364  100.0   91.510006
# 2022-01-06               100.0  ...  103.605481  100.0   91.479685
#
#                  BRPR3       HBSA3       EVEN3       UGPA3       NEOE3  \
# data
# 2021-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-03   96.853625   98.260870   95.902883   97.111417   97.839506
# 2022-01-04   94.254446   90.144928   94.385432   93.466300   96.234568
# 2022-01-05   89.740082   85.217391   89.984825   90.990371   94.382716
# 2022-01-06   89.056088   83.768116   90.743551   89.683631   93.273261
#
#                  TCSA3       ELET3
# data
# 2021-12-31  100.000000  100.000000
# 2022-01-03   94.182825   97.665370
# 2022-01-04   89.196676   95.570189
# 2022-01-05   81.994460   95.181084
# 2022-01-06   74.792244   95.031428
#
# [5 rows x 131 columns]

# %%
at.tail()
# Out:
#                  BPAC5      RAPT4       CMIG4       MELK3      DIRR3  \
# data
# 2022-07-25  100.517499  95.537109  114.691627  100.249730  89.613702
# 2022-07-26   98.573253  95.731488  113.419631   99.191685  88.301882
# 2022-07-27  100.517499  98.161221  119.355612  103.159352  91.663421
# 2022-07-28  100.906348  98.452789  118.719614  105.010930  95.516892
# 2022-07-29  103.628292  97.675274  119.143613  104.746419  97.074678
#
#                 PLPL3      BPAN4      BRAP4  27.635.189/0001-45  \
# data
# 2022-07-25  75.555017  63.874883  95.708112                 NaN
# 2022-07-26  74.903681  60.117537  95.581234                 NaN
# 2022-07-27  77.509027  60.493271  95.496649                 NaN
# 2022-07-28  81.417045  61.432608  96.765426                 NaN
# 2022-07-29  79.137367  62.371944  95.073723                 NaN
#
#             34.964.555/0001-75  ...       ITUB3      AURE3      WEGE3  \
# data                            ...
# 2022-07-25                 NaN  ...  106.765198  88.046662  81.486868
# 2022-07-26                 NaN  ...  106.237963  88.353659  80.625224
# 2022-07-27                 NaN  ...  106.132516  88.108061  82.687014
# 2022-07-28                 NaN  ...  106.765198  85.959084  85.948951
# 2022-07-29                 NaN  ...  106.923369  87.125672  86.287453
#
#                  BRPR3      HBSA3      EVEN3      UGPA3      NEOE3      TCSA3  \
# data
# 2022-07-25  116.000672  61.449275  70.561457  91.799236  96.090960  62.880886
# 2022-07-26  116.000672  61.739130  72.534143  89.287138  96.479992  60.110803
# 2022-07-27  120.153441  64.347826  75.720789  92.516978  99.203217  63.434903
# 2022-07-28  120.015015  66.376812  80.273141  91.655688  97.387734  67.313019
# 2022-07-29  116.554374  64.637681  81.031866  91.081494  96.026121  65.650970
#
#                  ELET3
# data
# 2022-07-25  136.756247
# 2022-07-26  136.146409
# 2022-07-27  138.341827
# 2022-07-28  138.585762
# 2022-07-29  139.683471
#
# [5 rows x 131 columns]

# %% [markdown]
# ### Loc e iloc

# %%
dv = pd.read_csv("dados_devers.csv", sep=";",
                 usecols=range(4),
                 index_col=0)

# %%
dv.head()
# Out:
#           Geração  Cursos 2022 Média FEA
# Devers
# Eddy          2.0            5       6,9
# André         3.0            4       8,7
# Kevyn         3.0            6       4,9
# Thais         3.0            4         8
# Bailinho      3.0            4       1,8

# %%
#buscar dados no DaraFrame pelo nome do índice
dv.loc["Eddy"]
# Out:
# Geração        2.0
# Cursos 2022      5
# Média FEA      6,9
# Name: Eddy, dtype: object

# %%
dv.loc["Bailinho"]
# Out:
#           Geração  Cursos 2022 Média FEA
# Devers
# Bailinho      3.0            4       1,8
# Bailinho      3.0            4       1,8

# %%
dv.loc[["Eddy", "André"]]
# Out:
#         Geração  Cursos 2022 Média FEA
# Devers
# Eddy        2.0            5       6,9
# André       3.0            4       8,7

# %%
#buscar dados no DaraFrame pelo nome do índice selecionando apenas algumas colunas
dv.loc[["Eddy", "Thais"], ["Geração", "Cursos 2022"]]
# Out:
#         Geração  Cursos 2022
# Devers
# Eddy        2.0            5
# Thais       3.0            4

# %%
#buscar dados no DaraFrame pelo nome do índice selecionando a partir de alguma coluna
dv.loc[["Eddy", "Thais"], "Cursos 2022":]
# Out:
#         Cursos 2022 Média FEA
# Devers
# Eddy              5       6,9
# Thais             4         8

# %%
# indica os índices a invés dos nomes das colunas ou linhas
dv.iloc[0]
# Out:
# Geração        2.0
# Cursos 2022      5
# Média FEA      6,9
# Name: Eddy, dtype: object

# %%
dv.iloc[0].name
# Out:
# 'Eddy'

# %%
dv.iloc[range(2), range(1)]
# Out:
#         Geração
# Devers
# Eddy        2.0
# André       3.0

# %%
dv.iloc[[9, 5, 6]]
# Out:
#            Geração  Cursos 2022 Média FEA
# Devers
# Ana Clara      3.0            6       7,5
# Sato           3.0            5       8,8
# Alice D.       2.0            4       6,8

# %%
del dv

# %%
at.head()
# Out:
#                  BPAC5       RAPT4       CMIG4       MELK3       DIRR3  \
# data
# 2021-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-03   96.153846   99.080037   98.245614   99.487179   95.594020
# 2022-01-04   94.423077   97.884085   98.169336   98.974359   92.210858
# 2022-01-05   86.730769   94.388224   95.041953   97.179487   85.995279
# 2022-01-06   84.574684   95.676173   92.982456   95.641026   84.107002
#
#                  PLPL3       BPAN4       BRAP4  27.635.189/0001-45  \
# data
# 2021-12-31  100.000000  100.000000  100.000000               100.0
# 2022-01-03   95.692308   95.786517   98.639456               100.0
# 2022-01-04   93.846154   88.295880   99.559824               100.0
# 2022-01-05   86.461538   88.576779   99.799920               100.0
# 2022-01-06   84.923077   89.513109  102.641056               100.0
#
#             34.964.555/0001-75  ...       ITUB3  AURE3       WEGE3  \
# data                            ...
# 2021-12-31               100.0  ...  100.000000  100.0  100.000000
# 2022-01-03               100.0  ...  101.613068  100.0   97.089145
# 2022-01-04               100.0  ...  103.867641  100.0   96.604002
# 2022-01-05               100.0  ...  101.770364  100.0   91.510006
# 2022-01-06               100.0  ...  103.605481  100.0   91.479685
#
#                  BRPR3       HBSA3       EVEN3       UGPA3       NEOE3  \
# data
# 2021-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-03   96.853625   98.260870   95.902883   97.111417   97.839506
# 2022-01-04   94.254446   90.144928   94.385432   93.466300   96.234568
# 2022-01-05   89.740082   85.217391   89.984825   90.990371   94.382716
# 2022-01-06   89.056088   83.768116   90.743551   89.683631   93.273261
#
#                  TCSA3       ELET3
# data
# 2021-12-31  100.000000  100.000000
# 2022-01-03   94.182825   97.665370
# 2022-01-04   89.196676   95.570189
# 2022-01-05   81.994460   95.181084
# 2022-01-06   74.792244   95.031428
#
# [5 rows x 131 columns]

# %%
#buscar dados no DaraFrame a partir dessa data
at.loc["2022-01-10":, :]
# Out:
#                  BPAC5       RAPT4       CMIG4       MELK3      DIRR3  \
# data
# 2022-01-10   83.602562   98.436063   92.677346   99.743590  81.825334
# 2022-01-11   85.741232   97.608096   95.347063   98.717949  82.218725
# 2022-01-12   89.629723  101.103956   96.720061   99.487179  83.241542
# 2022-01-13   90.407421   99.540018   96.872616   97.435897  83.556255
# 2022-01-14   92.157242  101.011960   97.101449   96.923077  85.601888
# ...                ...         ...         ...         ...        ...
# 2022-07-25  100.517499   95.537109  114.691627  100.249730  89.613702
# 2022-07-26   98.573253   95.731488  113.419631   99.191685  88.301882
# 2022-07-27  100.517499   98.161221  119.355612  103.159352  91.663421
# 2022-07-28  100.906348   98.452789  118.719614  105.010930  95.516892
# 2022-07-29  103.628292   97.675274  119.143613  104.746419  97.074678
#
#                 PLPL3      BPAN4       BRAP4  27.635.189/0001-45  \
# data
# 2022-01-10  89.230769  89.325843  106.642657                 NaN
# 2022-01-11  95.384615  91.011236  109.203681                 NaN
# 2022-01-12  96.923077  90.636704  111.004402                 NaN
# 2022-01-13  97.230769  90.074906  109.563826                 NaN
# 2022-01-14  96.923077  95.599251  110.124050                 NaN
# ...               ...        ...         ...                 ...
# 2022-07-25  75.555017  63.874883   95.708112                 NaN
# 2022-07-26  74.903681  60.117537   95.581234                 NaN
# 2022-07-27  77.509027  60.493271   95.496649                 NaN
# 2022-07-28  81.417045  61.432608   96.765426                 NaN
# 2022-07-29  79.137367  62.371944   95.073723                 NaN
#
#             34.964.555/0001-75  ...       ITUB3       AURE3      WEGE3  \
# data                            ...
# 2022-01-10                 NaN  ...  105.807622  100.000000  86.597938
# 2022-01-11                 NaN  ...  107.328148  100.000000  88.053366
# 2022-01-12                 NaN  ...  107.380580  100.000000  91.631292
# 2022-01-13                 NaN  ...  108.743810  100.000000  87.780473
# 2022-01-14                 NaN  ...  108.796242  100.000000  93.086719
# ...                        ...  ...         ...         ...        ...
# 2022-07-25                 NaN  ...  106.765198   88.046662  81.486868
# 2022-07-26                 NaN  ...  106.237963   88.353659  80.625224
# 2022-07-27                 NaN  ...  106.132516   88.108061  82.687014
# 2022-07-28                 NaN  ...  106.765198   85.959084  85.948951
# 2022-07-29                 NaN  ...  106.923369   87.125672  86.287453
#
#                  BRPR3      HBSA3      EVEN3      UGPA3      NEOE3      TCSA3  \
# data
# 2022-01-10   85.088919  80.869565  91.350531  87.895461  89.973205  72.576177
# 2022-01-11   87.140903  85.507246  92.109256  89.339752  91.405305  74.792244
# 2022-01-12   88.372093  85.797101  94.081942  92.847318  94.954421  77.839335
# 2022-01-13   87.277702  84.637681  93.171472  92.022008  94.020443  75.346260
# 2022-01-14   93.296854  84.057971  94.992413  90.508941  94.269504  75.900277
# ...                ...        ...        ...        ...        ...        ...
# 2022-07-25  116.000672  61.449275  70.561457  91.799236  96.090960  62.880886
# 2022-07-26  116.000672  61.739130  72.534143  89.287138  96.479992  60.110803
# 2022-07-27  120.153441  64.347826  75.720789  92.516978  99.203217  63.434903
# 2022-07-28  120.015015  66.376812  80.273141  91.655688  97.387734  67.313019
# 2022-07-29  116.554374  64.637681  81.031866  91.081494  96.026121  65.650970
#
#                  ELET3
# data
# 2022-01-10   88.237055
# 2022-01-11   89.314576
# 2022-01-12   94.013768
# 2022-01-13   94.043699
# 2022-01-14   94.612391
# ...                ...
# 2022-07-25  136.756247
# 2022-07-26  136.146409
# 2022-07-27  138.341827
# 2022-07-28  138.585762
# 2022-07-29  139.683471
#
# [140 rows x 131 columns]

# %% [markdown]
# ### Retorno a apresentação das bases

# %%
# unique - quando utilizado em series, retorna um array do numpy, dropando os duplicados
#drop_duplicates - para Data Frames
ct['ativo'].unique()
# Out:
# array(['Valores a Receber', 'ECOR3', 'AERI3', 'LWSA3', 'BPAC11', 'ITUB4',
#        'LREN3', 'PETR3', 'PETR4', 'BRDT3', 'BPAC5', 'RAPT4', 'CMIG4',
#        'MELK3', 'DIRR3', 'PLPL3', 'BPAN4', 'BRAP4', 'HAPV3', 'AZUL4',
#        'CMIG3', 'AESB3', 'FUTWINQ21', 'FUTWDOQ21', 'FUTDOLN21',
#        'Investimento no Exterior', 'Disponibilidade', 'AZUL11',
#        '27.635.189/0001-45', '34.964.555/0001-75', 'BRKM5', 'SULA11',
#        'AURA33', 'BRFS3', 'CSNA3', 'HYPE3', 'CRFB3', 'RADL3', 'BTOW3',
#        'CVCB1', 'MYPK3', 'RECV3', 'IFCM3', 'WEST3', 'BBAS3', 'TIMS3',
#        'EMBR3', 'GMAT3', 'RRRP3', 'GOAU4', 'SUZB3', 'FUTWDON21', 'LAME4',
#        'MRFG3', 'TGMA3', 'SOMA3', 'BBDC3', 'JSLG3', 'SBFG3', 'PNVL3',
#        'LAME3', 'ESPA3', 'LIGT3', 'RAIL3', 'GNDI3', 'BBDC4', 'GOAU3',
#        'PARD3', 'FUTDOLQ21', 'Valores a Pagar - Posição Vendida de CRFB3',
#        'VVAR3', 'MULT3', 'ALSO3', 'MOVI3', 'GGBR4', 'MDIA3', 'EQTL3',
#        'INTB3', 'BRAP3', 'ASAI3',
#        'Valores a Pagar - Posição Vendida de NEOE3', 'VALE3',
#        'Valores a Pagar', 'PSSA3', 'BOVA11',
#        'Valores a Pagar - Posição Vendida de SUZB3',
#        'Valores a Pagar - Posição Vendida de VIVT3',
#        'Valores a Pagar - Posição Vendida de CCRO3',
#        'Valores a Pagar - Posição Vendida de LREN3',
#        'Valores a Pagar - Posição Vendida de BRFS3',
#        'NTNB_07032006_15052035', 'PETZ3', 'FUTINDQ21', 'KLBN11', 'ALUP11',
#        'MELI34', 'ENEV3', 'CURY3',
#        'Valores a Pagar - Posição Vendida de ITUB4', 'CVCB3',
#        'OPD_DOL_VP82', 'POMO4', 'EZTC3', 'UGPA3', 'COGN3', 'EVEN3',
#        'TOTS3', 'NTCO3', 'MRVE3', 'CYRE3', 'MGLU3', 'ABEV3', 'YDUQ3',
#        'LTN_03072020_01102022', 'ABCB4', 'VALET84', 'VALET104',
#        'OPD_DOL_VPD1', 'ABEVT172', 'OPD_DOL_VPDT', 'OPD_DOL_VP91',
#        'BRKM3', 'UGPA1', 'LEVE3', 'MTRE3', 'HBOR3', 'ELET6', 'TEND3',
#        'TCSA3', 'TUPY3', '40.365.982/0001-30', '10.406.511/0001-61',
#        'SMFT3', 'AMER3', 'FUTWDOU21', 'CESP6', 'VAMO3', 'JBSS3',
#        'FUTDOLU21', 'LTN_05012018_01012022', 'B3SA3', 'IRBR3',
#        'NTNB_10012018_15082028', 'MGLUT220', 'NEOE3', 'PCAR3',
#        'FUTWINV21', 'FUTDOLV21', 'VIIA3', 'FUTWDOV21', 'RENT3', 'DASA3',
#        'LVTC3', 'ARZZ3', 'NTNB_14012015_15052055',
#        'LTN_21062018_01072022', 'OPD_IDI_FRFZ', 'FUTDI1F24', 'FUTINDV21',
#        'RANI3', 'CEAB3', 'IGTA3', 'OPD_IDI_FRHL', 'ARML3',
#        'Valores a Pagar - Posição Vendida de ARML3',
#        'Operações Compromissadas', 'ABEVU162', 'PETRI299', 'FUTDOLX21',
#        'FUTWDOX21', 'OPD_IDI_NQDD', 'IBOVL2', 'OPD_IDI_NQGL', 'IBOVL122',
#        'Valores a Pagar - Posição Vendida de VAMO3', 'IBOVJ120',
#        'FUTWINZ21', 'FUTWDOZ21', 'XPBR31', 'VBBR3', 'FUTDOLZ21', 'SYNE3',
#        'NTNF_10012014_01012025', 'FUTINDZ21', 'STBP3', 'IBOVK115',
#        'FUTWDOF22', 'RDOR3', 'VIVT3', 'IGTI11', 'FUTDOLF22', 'FUTDI1F23',
#        'Outras aplicações', 'FUTWDOG22', 'FUTDOLG22', 'FUTINDG22',
#        'FUTWING22', 'VIVA3', 'CMIN3', 'FUTWDOH22', 'CCRO3', 'BRML3',
#        'FUTDOLH22', 'ANIM3', 'AMER1', 'USIM5', 'FUTINDJ22',
#        '10.406.600/0001-08', 'FUTDOLJ22', 'FUTWDOJ22', 'FUTWINJ22',
#        'AMER9', 'FUTWDOK22', 'FUTDOLK22', 'LJQQ3', 'ITUB3', 'AURE3',
#        'WEGE3', 'BRPR3', 'Valores a Pagar - Posição Vendida de BOVA11',
#        'Outros valores mobiliários registrados na CVM objeto de oferta pública',
#        'PETRD328', 'HBSA3', 'FUTINDM22', 'FUTWDOM22', 'FUTDOLM22',
#        'FUTWINM22', 'FUTWDON22', 'FUTDOLN22',
#        'Valores a Pagar - Posição Vendida de BBDC4',
#        'Valores a Pagar - Posição Vendida de PETR3', 'FUTWDOQ22',
#        'FUTINDQ22', 'ELET3', 'FUTDOLQ22', 'FUTWINQ22'], dtype=object)

# %%
ct['ativo'].unique()[0]
# Out:
# 'Valores a Receber'

# %%
#compara número de ativo no DataFrame ct com o número de colunas no DataFrame at
print(len(ct["ativo"].unique()), "vs", len(at.columns))
print(ct["ativo"].unique()[0])
# Out:
# 236 vs 131
# Valores a Receber

# %% [markdown]
# #### Set Theory
# ![set_theory](set_theory.png)
# ![set_theory_ativos](set_theory_ativos.png)

# %%
# Sets - link para métodos de set: https://www.w3schools.com/python/python_ref_set.asp
x = {'Petrobras', 'Itaú', 'Suzano'}
y = {'Eletrobras', 'Bradesco', 'Suzano'}

#Subtrai os elementos de y em x
z = x.difference(y)
z
# Out:
# {'Itaú', 'Petrobras'}

# %%
y.difference(x)
# Out:
# {'Bradesco', 'Eletrobras'}

# %%
#dierença simétrica - pega tudo fora da intersecção
x.symmetric_difference(y)
# Out:
# {'Bradesco', 'Eletrobras', 'Itaú', 'Petrobras'}

# %%
x.intersection(y)
# Out:
# {'Suzano'}

# %%
# acessar colunas do dataframe de ativos
at.columns
# Out:
# Index(['BPAC5', 'RAPT4', 'CMIG4', 'MELK3', 'DIRR3', 'PLPL3', 'BPAN4', 'BRAP4',
#        '27.635.189/0001-45', '34.964.555/0001-75',
#        ...
#        'ITUB3', 'AURE3', 'WEGE3', 'BRPR3', 'HBSA3', 'EVEN3', 'UGPA3', 'NEOE3',
#        'TCSA3', 'ELET3'],
#       dtype='object', length=131)

# %%
#tudo que tenho nas colunas, tenho nos ativos também, então dá vazio
set(at.columns.unique()).difference(ct["ativo"].unique())
# Out:
# set()

# %%
# por outro lado, há ativos nas carteiras que não estão no DataFrame
set(ct["ativo"].unique()).difference(at.columns.unique())
# Out:
# {'ABEVT172',
#  'ABEVU162',
#  'ALUP11',
#  'AMER1',
#  'AMER9',
#  'AURA33',
#  'AZUL11',
#  'BOVA11',
#  'BPAC11',
#  'CVCB1',
#  'Disponibilidade',
#  'FUTDI1F23',
#  'FUTDI1F24',
#  'FUTDOLF22',
#  'FUTDOLG22',
#  'FUTDOLH22',
#  'FUTDOLJ22',
#  'FUTDOLK22',
#  'FUTDOLM22',
#  'FUTDOLN21',
#  'FUTDOLN22',
#  'FUTDOLQ21',
#  'FUTDOLQ22',
#  'FUTDOLU21',
#  'FUTDOLV21',
#  'FUTDOLX21',
#  'FUTDOLZ21',
#  'FUTINDG22',
#  'FUTINDJ22',
#  'FUTINDM22',
#  'FUTINDQ21',
#  'FUTINDQ22',
#  'FUTINDV21',
#  'FUTINDZ21',
#  'FUTWDOF22',
#  'FUTWDOG22',
#  'FUTWDOH22',
#  'FUTWDOJ22',
#  'FUTWDOK22',
#  'FUTWDOM22',
#  'FUTWDON21',
#  'FUTWDON22',
#  'FUTWDOQ21',
#  'FUTWDOQ22',
#  'FUTWDOU21',
#  'FUTWDOV21',
#  'FUTWDOX21',
#  'FUTWDOZ21',
#  'FUTWING22',
#  'FUTWINJ22',
#  'FUTWINM22',
#  'FUTWINQ21',
#  'FUTWINQ22',
#  'FUTWINV21',
#  'FUTWINZ21',
#  'IBOVJ120',
#  'IBOVK115',
#  'IBOVL122',
#  'IBOVL2',
#  'IGTI11',
#  'Investimento no Exterior',
#  'KLBN11',
#  'LTN_03072020_01102022',
#  'LTN_05012018_01012022',
#  'LTN_21062018_01072022',
#  'MELI34',
#  'MGLUT220',
#  'NTNB_07032006_15052035',
#  'NTNB_10012018_15082028',
#  'NTNB_14012015_15052055',
#  'NTNF_10012014_01012025',
#  'OPD_DOL_VP82',
#  'OPD_DOL_VP91',
#  'OPD_DOL_VPD1',
#  'OPD_DOL_VPDT',
#  'OPD_IDI_FRFZ',
#  'OPD_IDI_FRHL',
#  'OPD_IDI_NQDD',
#  'OPD_IDI_NQGL',
#  'Operações Compromissadas',
#  'Outras aplicações',
#  'Outros valores mobiliários registrados na CVM objeto de oferta pública',
#  'PETRD328',
#  'PETRI299',
#  'SULA11',
#  'UGPA1',
#  'VALET104',
#  'VALET84',
#  'VIVT3',
#  'Valores a Pagar',
#  'Valores a Pagar - Posição Vendida de ARML3',
#  'Valores a Pagar - Posição Vendida de BBDC4',
#  'Valores a Pagar - Posição Vendida de BOVA11',
#  'Valores a Pagar - Posição Vendida de BRFS3',
#  'Valores a Pagar - Posição Vendida de CCRO3',
#  'Valores a Pagar - Posição Vendida de CRFB3',
#  'Valores a Pagar - Posição Vendida de ITUB4',
#  'Valores a Pagar - Posição Vendida de LREN3',
#  'Valores a Pagar - Posição Vendida de NEOE3',
#  'Valores a Pagar - Posição Vendida de PETR3',
#  'Valores a Pagar - Posição Vendida de SUZB3',
#  'Valores a Pagar - Posição Vendida de VAMO3',
#  'Valores a Pagar - Posição Vendida de VIVT3',
#  'Valores a Receber',
#  'XPBR31'}

# %%
ct.loc[ct["ativo"].isin(at.columns), ["ativo", "ativo_desc"]].drop_duplicates()
# Out:
#       ativo                                         ativo_desc
# 1     ECOR3           Ações e outros TVM cedidos em empréstimo
# 2     AERI3           Ações e outros TVM cedidos em empréstimo
# 3     LWSA3           Ações e outros TVM cedidos em empréstimo
# 5     ITUB4           Ações e outros TVM cedidos em empréstimo
# 6     LREN3           Ações e outros TVM cedidos em empréstimo
# ...     ...                                                ...
# 1799  TCSA3                                              Ações
# 1932  HBSA3  Obrigações por ações e outros TVM recebidos em...
# 2141  MRFG3           Ações e outros TVM cedidos em empréstimo
# 2241  ELET3                                              Ações
# 2289  ELET3  Obrigações por ações e outros TVM recebidos em...
#
# [227 rows x 2 columns]

# %%
ct.loc[ct["ativo"].isin(at.columns), "ativo_desc"].unique()
# Out:
# array(['Ações e outros TVM cedidos em empréstimo', 'Ações',
#        'Cotas de Fundos',
#        'Obrigações por ações e outros TVM recebidos em empréstimo'],
#       dtype=object)

# %%
pd.set_option('max_colwidth', None)
ct[["nome_gestor", "nome_fundo"]].drop_duplicates().reset_index(drop=True)
# Out:
#                                 nome_gestor  \
# 0  TOWER THREE RV GESTORA DE RECURSOS LTDA.
# 1               KAPITALO INVESTIMENTOS LTDA
#
#                                                           nome_fundo
# 0  T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO PRIVADO LONG BIASED
# 1              KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM AÇÕES

# %%
pd.reset_option('^display.', silent=True)

# %% [markdown]
# ## 2. Métodos Úteis

# %% [markdown]
# ### 2.1.1 Groupby
# Função de agregação: agrupo por certa coisa e tenta tirar um insight a partir disso (soma, média, etc.).

# %%
# nunique é a função agregadora aqui (count de valores únicos), mas poderia ser outra, como sum,  count, etc.
ct.groupby("nome_fundo").nunique()[["ativo"]]
# Out:
#                                                     ativo
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...    176
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...    135

# %%
ct[["nome_fundo", "data", "ativo"]].groupby(["nome_fundo", "data"]).count()
# Out:
#                                                                ativo
# nome_fundo                                         data
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM... 2021-06-30    133
#                                                    2021-07-30    140
#                                                    2021-08-31    144
#                                                    2021-09-30    126
#                                                    2021-10-29    127
#                                                    2021-11-30    125
#                                                    2021-12-31    121
#                                                    2022-01-31    123
#                                                    2022-02-25    140
#                                                    2022-03-31    121
#                                                    2022-04-29    138
#                                                    2022-05-31    135
#                                                    2022-06-30    137
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P... 2021-06-30     40
#                                                    2021-07-30     43
#                                                    2021-08-31     52
#                                                    2021-09-30     53
#                                                    2021-10-29     53
#                                                    2021-11-30     49
#                                                    2021-12-31     46
#                                                    2022-01-31     41
#                                                    2022-02-25     38
#                                                    2022-03-31     46
#                                                    2022-04-29     43
#                                                    2022-05-31     36
#                                                    2022-06-30     42

# %% [markdown]
# ### 2.1.2 Pivot Table
# Mesmo esquema do groupby. Tabela formato wide.

# %%
#lambda define a função na hora
ct.pivot_table("ativo_desc", index="nome_fundo", columns="data", aggfunc=lambda x: len(x.unique()))
# Out:
# data                                                2021-06-30  2021-07-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          16          16
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...           8           9
#
# data                                                2021-08-31  2021-09-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          16          16
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          13          14
#
# data                                                2021-10-29  2021-11-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          15          15
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          13          13
#
# data                                                2021-12-31  2022-01-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          14          14
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          13          12
#
# data                                                2022-02-25  2022-03-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          14          16
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          13          13
#
# data                                                2022-04-29  2022-05-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          15          14
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          12          11
#
# data                                                2022-06-30
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          14
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          11

# %%
ct.pivot_table("ativo", index="nome_fundo", columns="data", aggfunc=lambda x: len(x.unique()))
# Out:
# data                                                2021-06-30  2021-07-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         107         106
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          40          42
#
# data                                                2021-08-31  2021-09-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         103          97
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          50          51
#
# data                                                2021-10-29  2021-11-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          94          93
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          51          48
#
# data                                                2021-12-31  2022-01-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          93          95
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          44          40
#
# data                                                2022-02-25  2022-03-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          95          97
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          37          44
#
# data                                                2022-04-29  2022-05-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          96          95
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          43          36
#
# data                                                2022-06-30
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...          95
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          42

# %%
# É tipo uma tabela dinâmica
pivoted_table = ct.pivot_table("ativo", index="nome_fundo", columns="data", aggfunc="count")
pivoted_table
# Out:
# data                                                2021-06-30  2021-07-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         133         140
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          40          43
#
# data                                                2021-08-31  2021-09-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         144         126
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          52          53
#
# data                                                2021-10-29  2021-11-30  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         127         125
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          53          49
#
# data                                                2021-12-31  2022-01-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         121         123
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          46          41
#
# data                                                2022-02-25  2022-03-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         140         121
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          38          46
#
# data                                                2022-04-29  2022-05-31  \
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         138         135
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          43          36
#
# data                                                2022-06-30
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM...         137
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P...          42

# %% [markdown]
# ### 2.1.3 Melt
# Tabela formato long.

# %%
pivoted_table.melt(ignore_index=False).head(6)
# Out:
#                                                          data  value
# nome_fundo
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM... 2021-06-30    133
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P... 2021-06-30     40
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM... 2021-07-30    140
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P... 2021-07-30     43
# KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM... 2021-08-31    144
# T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO P... 2021-08-31     52

# %% [markdown]
# ### 2.2.1 Diff
# Diff é fazer a subtração de um valor pelo anterior (variação absoluta)

# %%
#plota série de números randômicos com reta estacionária
np.random.seed(420)
rand_series = np.random.rand(100)
plt.plot(np.arange(100), rand_series)

# %%
# cria uma linha de tendência
x = np.arange(100).reshape(-1, 1)
y_tendencia = (rand_series * np.arange(1, 20, .19)).reshape(-1, 1)
pred = LinearRegression().fit(x, y_tendencia).predict(x)

# %%
fix, ax = plt.subplots()
ax.plot(x, y_tendencia)
ax.plot(pred)
plt.show()

# %%
#(t1 - t0) --> tende a tirar a tendência da nossa série
y = pd.Series(y_tendencia.flatten()).diff()
pred = LinearRegression().fit(x, y.fillna(0)).predict(x)

fig, ax = plt.subplots()

# função plot do pandas
y.diff().plot()
ax.plot(pred)
plt.show()

# %% [markdown]
# ### 2.2.2 Pct_change
# Retorno diário
# (x1 - x0)/x0 (diferença relativa)

# %%
#shiift joga o dataframe para frente
((at - at.shift(1)) / at).head()
# Out:
#                BPAC5     RAPT4     CMIG4     MELK3     DIRR3     PLPL3  \
# data
# 2021-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-03 -0.040000 -0.009285 -0.017857 -0.005155 -0.046091 -0.045016
# 2022-01-04 -0.018330 -0.012218 -0.000777 -0.005181 -0.036689 -0.019672
# 2022-01-05 -0.088692 -0.037037 -0.032905 -0.018470 -0.072278 -0.085409
# 2022-01-06 -0.025493  0.013462 -0.022149 -0.016086 -0.022451 -0.018116
#
#                BPAN4     BRAP4  27.635.189/0001-45  34.964.555/0001-75  ...  \
# data                                                                    ...
# 2021-12-31       NaN       NaN                 NaN                 NaN  ...
# 2022-01-03 -0.043988 -0.013793                 0.0                 0.0  ...
# 2022-01-04 -0.084836  0.009244                 0.0                 0.0  ...
# 2022-01-05  0.003171  0.002406                 0.0                 0.0  ...
# 2022-01-06  0.010460  0.027680                 0.0                 0.0  ...
#
#                ITUB3  AURE3     WEGE3     BRPR3     HBSA3     EVEN3     UGPA3  \
# data
# 2021-12-31       NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-03  0.015875    0.0 -0.029981 -0.032486 -0.017699 -0.042722 -0.029745
# 2022-01-04  0.021706    0.0 -0.005022 -0.027576 -0.090032 -0.016077 -0.038999
# 2022-01-05 -0.020608    0.0 -0.055666 -0.050305 -0.057823 -0.048904 -0.027211
# 2022-01-06  0.017713    0.0 -0.000331 -0.007680 -0.017301  0.008361 -0.014571
#
#                NEOE3     TCSA3     ELET3
# data
# 2021-12-31       NaN       NaN       NaN
# 2022-01-03 -0.022082 -0.061765 -0.023904
# 2022-01-04 -0.016677 -0.055901 -0.021923
# 2022-01-05 -0.019621 -0.087838 -0.004088
# 2022-01-06 -0.011895 -0.096296 -0.001575
#
# [5 rows x 131 columns]

# %%
#mesma coisa, de outra forma
(at.diff() / at).head()
# Out:
#                BPAC5     RAPT4     CMIG4     MELK3     DIRR3     PLPL3  \
# data
# 2021-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-03 -0.040000 -0.009285 -0.017857 -0.005155 -0.046091 -0.045016
# 2022-01-04 -0.018330 -0.012218 -0.000777 -0.005181 -0.036689 -0.019672
# 2022-01-05 -0.088692 -0.037037 -0.032905 -0.018470 -0.072278 -0.085409
# 2022-01-06 -0.025493  0.013462 -0.022149 -0.016086 -0.022451 -0.018116
#
#                BPAN4     BRAP4  27.635.189/0001-45  34.964.555/0001-75  ...  \
# data                                                                    ...
# 2021-12-31       NaN       NaN                 NaN                 NaN  ...
# 2022-01-03 -0.043988 -0.013793                 0.0                 0.0  ...
# 2022-01-04 -0.084836  0.009244                 0.0                 0.0  ...
# 2022-01-05  0.003171  0.002406                 0.0                 0.0  ...
# 2022-01-06  0.010460  0.027680                 0.0                 0.0  ...
#
#                ITUB3  AURE3     WEGE3     BRPR3     HBSA3     EVEN3     UGPA3  \
# data
# 2021-12-31       NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-03  0.015875    0.0 -0.029981 -0.032486 -0.017699 -0.042722 -0.029745
# 2022-01-04  0.021706    0.0 -0.005022 -0.027576 -0.090032 -0.016077 -0.038999
# 2022-01-05 -0.020608    0.0 -0.055666 -0.050305 -0.057823 -0.048904 -0.027211
# 2022-01-06  0.017713    0.0 -0.000331 -0.007680 -0.017301  0.008361 -0.014571
#
#                NEOE3     TCSA3     ELET3
# data
# 2021-12-31       NaN       NaN       NaN
# 2022-01-03 -0.022082 -0.061765 -0.023904
# 2022-01-04 -0.016677 -0.055901 -0.021923
# 2022-01-05 -0.019621 -0.087838 -0.004088
# 2022-01-06 -0.011895 -0.096296 -0.001575
#
# [5 rows x 131 columns]

# %%
#mesma coisa, de outra forma mais simples
at.pct_change().head()
# Out:
#                BPAC5     RAPT4     CMIG4     MELK3     DIRR3     PLPL3  \
# data
# 2021-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-03 -0.038462 -0.009200 -0.017544 -0.005128 -0.044060 -0.043077
# 2022-01-04 -0.018000 -0.012071 -0.000776 -0.005155 -0.035391 -0.019293
# 2022-01-05 -0.081466 -0.035714 -0.031857 -0.018135 -0.067406 -0.078689
# 2022-01-06 -0.024860  0.013645 -0.021669 -0.015831 -0.021958 -0.017794
#
#                BPAN4     BRAP4  27.635.189/0001-45  34.964.555/0001-75  ...  \
# data                                                                    ...
# 2021-12-31       NaN       NaN                 NaN                 NaN  ...
# 2022-01-03 -0.042135 -0.013605                 0.0                 0.0  ...
# 2022-01-04 -0.078201  0.009331                 0.0                 0.0  ...
# 2022-01-05  0.003181  0.002412                 0.0                 0.0  ...
# 2022-01-06  0.010571  0.028468                 0.0                 0.0  ...
#
#                ITUB3  AURE3     WEGE3     BRPR3     HBSA3     EVEN3     UGPA3  \
# data
# 2021-12-31       NaN    NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-03  0.016131    0.0 -0.029109 -0.031464 -0.017391 -0.040971 -0.028886
# 2022-01-04  0.022188    0.0 -0.004997 -0.026836 -0.082596 -0.015823 -0.037535
# 2022-01-05 -0.020192    0.0 -0.052731 -0.047896 -0.054662 -0.046624 -0.026490
# 2022-01-06  0.018032    0.0 -0.000331 -0.007622 -0.017007  0.008432 -0.014361
#
#                NEOE3     TCSA3     ELET3
# data
# 2021-12-31       NaN       NaN       NaN
# 2022-01-03 -0.021605 -0.058172 -0.023346
# 2022-01-04 -0.016404 -0.052941 -0.021453
# 2022-01-05 -0.019243 -0.080745 -0.004071
# 2022-01-06 -0.011755 -0.087838 -0.001572
#
# [5 rows x 131 columns]

# %%
#sendo uma diferença, a primeira linha não terá variação pois é a base para os demais cálculos. 
#Então, há diferentes formas de lidar com isso.

#Uma delas, é simplesmente ignorando essa primeira linha
at.pct_change().iloc[1:]
# Out:
#                BPAC5     RAPT4     CMIG4     MELK3     DIRR3     PLPL3  \
# data
# 2022-01-03 -0.038462 -0.009200 -0.017544 -0.005128 -0.044060 -0.043077
# 2022-01-04 -0.018000 -0.012071 -0.000776 -0.005155 -0.035391 -0.019293
# 2022-01-05 -0.081466 -0.035714 -0.031857 -0.018135 -0.067406 -0.078689
# 2022-01-06 -0.024860  0.013645 -0.021669 -0.015831 -0.021958 -0.017794
# 2022-01-07  0.000000  0.056731  0.005742 -0.008043 -0.004677  0.101449
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25 -0.013359  0.010277  0.015962  0.010667 -0.038698 -0.068273
# 2022-07-26 -0.019342  0.002035 -0.011091 -0.010554 -0.014639 -0.008621
# 2022-07-27  0.019724  0.025381  0.052336  0.040000  0.038069  0.034783
# 2022-07-28  0.003868  0.002970 -0.005329  0.017949  0.042039  0.050420
# 2022-07-29  0.026975 -0.007897  0.003571 -0.002519  0.016309 -0.028000
#
#                BPAN4     BRAP4  27.635.189/0001-45  34.964.555/0001-75  ...  \
# data                                                                    ...
# 2022-01-03 -0.042135 -0.013605                 0.0                 0.0  ...
# 2022-01-04 -0.078201  0.009331                 0.0                 0.0  ...
# 2022-01-05  0.003181  0.002412                 0.0                 0.0  ...
# 2022-01-06  0.010571  0.028468                 0.0                 0.0  ...
# 2022-01-07  0.009414  0.039376                 0.0                 0.0  ...
# ...              ...       ...                 ...                 ...  ...
# 2022-07-25 -0.039548  0.013435                 0.0                 0.0  ...
# 2022-07-26 -0.058824 -0.001326                 0.0                 0.0  ...
# 2022-07-27  0.006250 -0.000885                 0.0                 0.0  ...
# 2022-07-28  0.015528  0.013286                 0.0                 0.0  ...
# 2022-07-29  0.015291 -0.017483                 0.0                 0.0  ...
#
#                ITUB3     AURE3     WEGE3     BRPR3     HBSA3     EVEN3  \
# data
# 2022-01-03  0.016131  0.000000 -0.029109 -0.031464 -0.017391 -0.040971
# 2022-01-04  0.022188  0.000000 -0.004997 -0.026836 -0.082596 -0.015823
# 2022-01-05 -0.020192  0.000000 -0.052731 -0.047896 -0.054662 -0.046624
# 2022-01-06  0.018032  0.000000 -0.000331 -0.007622 -0.017007  0.008432
# 2022-01-07  0.015688  0.000000 -0.025191 -0.009217  0.006920 -0.001672
# ...              ...       ...       ...       ...       ...       ...
# 2022-07-25  0.013514 -0.011716  0.030027 -0.002381  0.019231 -0.016913
# 2022-07-26 -0.004938  0.003487 -0.010574  0.000000  0.004717  0.027957
# 2022-07-27 -0.000993 -0.002780  0.025573  0.035800  0.042254  0.043933
# 2022-07-28  0.005961 -0.024390  0.039449 -0.001152  0.031532  0.060120
# 2022-07-29  0.001481  0.013571  0.003938 -0.028835 -0.026201  0.009452
#
#                UGPA3     NEOE3     TCSA3     ELET3
# data
# 2022-01-03 -0.028886 -0.021605 -0.058172 -0.023346
# 2022-01-04 -0.037535 -0.016404 -0.052941 -0.021453
# 2022-01-05 -0.026490 -0.019243 -0.080745 -0.004071
# 2022-01-06 -0.014361 -0.011755 -0.087838 -0.001572
# 2022-01-07 -0.006902 -0.019359  0.022222 -0.043780
# ...              ...       ...       ...       ...
# 2022-07-25  0.026485  0.031315 -0.034043  0.004929
# 2022-07-26 -0.027365  0.004049 -0.044053 -0.004459
# 2022-07-27  0.036174  0.028226  0.055300  0.016125
# 2022-07-28 -0.009310 -0.018301  0.061135  0.001763
# 2022-07-29 -0.006265 -0.013981 -0.024691  0.007921
#
# [145 rows x 131 columns]

# %%
#Ou você pode preencher a linha com algum valor que deseje, como 0 (melhor do que ignorar).
filling_first = at.pct_change()
filling_first.iloc[0] = 0
filling_first.head()
# Out:
#                BPAC5     RAPT4     CMIG4     MELK3     DIRR3     PLPL3  \
# data
# 2021-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-01-03 -0.038462 -0.009200 -0.017544 -0.005128 -0.044060 -0.043077
# 2022-01-04 -0.018000 -0.012071 -0.000776 -0.005155 -0.035391 -0.019293
# 2022-01-05 -0.081466 -0.035714 -0.031857 -0.018135 -0.067406 -0.078689
# 2022-01-06 -0.024860  0.013645 -0.021669 -0.015831 -0.021958 -0.017794
#
#                BPAN4     BRAP4  27.635.189/0001-45  34.964.555/0001-75  ...  \
# data                                                                    ...
# 2021-12-31  0.000000  0.000000                 0.0                 0.0  ...
# 2022-01-03 -0.042135 -0.013605                 0.0                 0.0  ...
# 2022-01-04 -0.078201  0.009331                 0.0                 0.0  ...
# 2022-01-05  0.003181  0.002412                 0.0                 0.0  ...
# 2022-01-06  0.010571  0.028468                 0.0                 0.0  ...
#
#                ITUB3  AURE3     WEGE3     BRPR3     HBSA3     EVEN3     UGPA3  \
# data
# 2021-12-31  0.000000    0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022-01-03  0.016131    0.0 -0.029109 -0.031464 -0.017391 -0.040971 -0.028886
# 2022-01-04  0.022188    0.0 -0.004997 -0.026836 -0.082596 -0.015823 -0.037535
# 2022-01-05 -0.020192    0.0 -0.052731 -0.047896 -0.054662 -0.046624 -0.026490
# 2022-01-06  0.018032    0.0 -0.000331 -0.007622 -0.017007  0.008432 -0.014361
#
#                NEOE3     TCSA3     ELET3
# data
# 2021-12-31  0.000000  0.000000  0.000000
# 2022-01-03 -0.021605 -0.058172 -0.023346
# 2022-01-04 -0.016404 -0.052941 -0.021453
# 2022-01-05 -0.019243 -0.080745 -0.004071
# 2022-01-06 -0.011755 -0.087838 -0.001572
#
# [5 rows x 131 columns]

# %% [markdown]
# ## 3. Aplicações Úteis

# %% [markdown]
# ### 3.1 Cálculo de Retorno

# %%
#top 5 ações com maiores retornos a partir dos retornos diários, somando a 1 para não obter zero.
((at.pct_change() + 1).prod() - 1).sort_values(ascending=False)[:5]
# Out:
# HYPE3    0.530917
# ELET6    0.490324
# PETR4    0.463378
# PETR3    0.444781
# ELET3    0.396835
# dtype: float64

# %%
((at.pct_change() + 1).prod() - 1)[:3]
# Out:
# BPAC5    0.036283
# RAPT4   -0.023247
# CMIG4    0.191436
# dtype: float64

# %%
(at.pct_change() + 1).cumprod().iloc[:, :3].plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %%
top_10_geral = ((at.pct_change() + 1).prod() - 1).sort_values(ascending=False)[:10]

# %% [markdown]
# ### 3.2 Cálculo Para Cada Fundo

# %%
ativos_tarkus = (ct.loc[ct["ativo"].isin(at.columns) &
                        (ct["nome_fundo"]=="KAPITALO TARKUS MÁSTER FUNDO DE INVESTIMENTO EM AÇÕES"),
                        "ativo"]
                   .unique()
)
ativos_t3 = (ct["ativo"][ct["ativo"].isin(at.columns) &
                         (ct["nome_fundo"]=="T3 FUNDO DE INVESTIMENTO MULTIMERCADO CRÉDITO PRIVADO LONG BIASED")]
                   .unique()
)

# %%
top_10_tarkus = ((at[ativos_tarkus].pct_change() + 1).prod() - 1).sort_values(ascending=False)[:10]
top_10_t3 = ((at[ativos_t3].pct_change() + 1).prod() - 1).sort_values(ascending=False)[:10]

# %% [markdown]
# ### 3.3 Juntando os Resultados

# %%
#concatenar listas
pd.concat([top_10_geral.rename("Geral"),
           top_10_tarkus.rename("Kapitalo Tarkus"),
           top_10_t3.rename("Tower Three Long Biased")], axis=1)
# Out:
#           Geral  Kapitalo Tarkus  Tower Three Long Biased
# HYPE3  0.530917         0.530917                 0.530917
# ELET6  0.490324         0.490324                 0.490324
# PETR4  0.463378         0.463378                 0.463378
# PETR3  0.444781         0.444781                 0.444781
# ELET3  0.396835         0.396835                 0.396835
# MDIA3  0.322150              NaN                 0.322150
# RECV3  0.320227         0.320227                 0.320227
# BBAS3  0.316901         0.316901                 0.316901
# MULT3  0.285482              NaN                 0.285482
# CMIG3  0.254412         0.254412                      NaN
# ASAI3       NaN         0.232921                      NaN
# CRFB3       NaN         0.232136                      NaN
# CURY3       NaN              NaN                 0.247724

# %% [markdown]
# ![](joins.png)

# %%
#merge só pode ser usado com Dataframe, não com séries. Outer = full join
(pd.DataFrame(top_10_geral.rename("Geral"))
   .merge(top_10_tarkus.rename("Tarkus"),
          left_index=True,
          right_index=True,
          how="outer")
   .merge(top_10_t3.rename("Tower Three Long Biased"),
          left_index=True,
          right_index=True,
          how="outer")
).sort_values("Geral", ascending=False)
# Out:
#           Geral    Tarkus  Tower Three Long Biased
# HYPE3  0.530917  0.530917                 0.530917
# ELET6  0.490324  0.490324                 0.490324
# PETR4  0.463378  0.463378                 0.463378
# PETR3  0.444781  0.444781                 0.444781
# ELET3  0.396835  0.396835                 0.396835
# MDIA3  0.322150       NaN                 0.322150
# RECV3  0.320227  0.320227                 0.320227
# BBAS3  0.316901  0.316901                 0.316901
# MULT3  0.285482       NaN                 0.285482
# CMIG3  0.254412  0.254412                      NaN
# ASAI3       NaN  0.232921                      NaN
# CRFB3       NaN  0.232136                      NaN
# CURY3       NaN       NaN                 0.247724

# %%
(pd.DataFrame(top_10_geral.rename("Geral"))
   .join(top_10_tarkus.rename("Tarkus"),
          how="outer")
   .join(top_10_t3.rename("Tower Three Long Biased"),
          how="outer")
).sort_values("Geral", ascending=False)
# Out:
#           Geral    Tarkus  Tower Three Long Biased
# HYPE3  0.530917  0.530917                 0.530917
# ELET6  0.490324  0.490324                 0.490324
# PETR4  0.463378  0.463378                 0.463378
# PETR3  0.444781  0.444781                 0.444781
# ELET3  0.396835  0.396835                 0.396835
# MDIA3  0.322150       NaN                 0.322150
# RECV3  0.320227  0.320227                 0.320227
# BBAS3  0.316901  0.316901                 0.316901
# MULT3  0.285482       NaN                 0.285482
# CMIG3  0.254412  0.254412                      NaN
# ASAI3       NaN  0.232921                      NaN
# CRFB3       NaN  0.232136                      NaN
# CURY3       NaN       NaN                 0.247724

# %% [markdown]
# #### **Bônus:** Vídeo sobre cálculo de retornos FEA.dev
#
# https://www.youtube.com/watch?v=8FjerLRybkg&t=5s
